# %%
import pandas as pd

s = pd.Series([0, 1])
ax = s.plot.hist()
ax.figure.savefig('demo-file.pdf')

# %%
cvsData = pd.read_csv("netflix.csv")

# %%
cvsData
# Out:
#         sov_no     tipi                                       baslik  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       yonetmen  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
import pdfkit as pdf
deneme = cvsData.tipi.hist()
cvsData.to('deneme.html')

pdf.from_file('deneme.html','deneme.pdf')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pdfkit\configuration.py in __init__(self, wkhtmltopdf, meta_tag_prefix)
#      20         try:
# ---> 21             with open(self.wkhtmltopdf) as f:
#      22                 pass
#
# FileNotFoundError: [Errno 2] No such file or directory: b''
#
# During handling of the above exception, another exception occurred:
#
# OSError                                   Traceback (most recent call last)
# <ipython-input-13-0b5ab72c1304> in <module>
#       3 cvsData.to_html('deneme.html')
#       4
# ----> 5 pdf.from_file('deneme.html','deneme.pdf')
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pdfkit\api.py in from_file(input, output_path, options, toc, cover, css, configuration, cover_first)
#      44     """
#      45
# ...
