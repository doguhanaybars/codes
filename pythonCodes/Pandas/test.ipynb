# %%
import pandas as pd

# %%
pd.read_csv("netflix.csv")
datatest = pd.read_csv("netflix.csv")

# %%
datatest
# Out:
#         sov_no     tipi                                       baslik  \
# 0     81145628    Movie      Norm of the North: King Sized Adventure
# 1     80117401    Movie                   Jandino: Whatever it Takes
# 2     70234439  TV Show                           Transformers Prime
# 3     80058654  TV Show             Transformers: Robots in Disguise
# 4     80125979    Movie                                 #realityhigh
# ...        ...      ...                                          ...
# 6229  80000063  TV Show                                 Red vs. Blue
# 6230  70286564  TV Show                                        Maron
# 6231  80116008    Movie       Little Baby Bum: Nursery Rhyme Friends
# 6232  70281022  TV Show  A Young Doctor's Notebook and Other Stories
# 6233  70153404  TV Show                                      Friends
#
#                       yonetmen  \
# 0     Richard Finn, Tim Maltby
# 1                          NaN
# 2                          NaN
# ...

# %%
data1 = datatest.tipi

# %%
data1.hist()

# %%
datatest.columns
# Out:
# Index(['sov_no', 'tipi', 'baslik', 'yonetmen', 'oyuncular', 'ulke',
#        'eklenme_tarihi', 'cikis_tarihi', 'sure', 'kategori', 'aciklama'],
#       dtype='object')

# %%
looping = len(datatest.columns)+1

# %%
for i in range(1,int(looping)):
    deneme = datatest.columns
    pd.DataFrame(datatest)

# %%
dtfrm= pd.DataFrame(datatest)

# %%
dtfrm.
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-31-b369702825f6> in <module>
# ----> 1 j.hist()
#
# AttributeError: 'str' object has no attribute 'hist'

# %%
pd.Series(datatest.columns[2])
# Out:
# 0    baslik
# dtype: object

# %%
pd.Series(datatest.tipi)
# Out:
# 0         Movie
# 1         Movie
# 2       TV Show
# 3       TV Show
# 4         Movie
#          ...
# 6229    TV Show
# 6230    TV Show
# 6231      Movie
# 6232    TV Show
# 6233    TV Show
# Name: tipi, Length: 6234, dtype: object
